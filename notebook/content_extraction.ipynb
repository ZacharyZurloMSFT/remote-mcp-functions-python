# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: aiohttp in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from -r requirements.txt (line 1)) (3.13.2)
# Requirement already satisfied: azure-identity in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from -r requirements.txt (line 2)) (1.25.1)
# Collecting azure-storage-blob (from -r requirements.txt (line 3))
#   Using cached azure_storage_blob-12.27.1-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: python-dotenv in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from -r requirements.txt (line 4)) (1.2.1)
# Requirement already satisfied: requests in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from -r requirements.txt (line 5)) (2.32.5)
# Requirement already satisfied: Pillow in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from -r requirements.txt (line 6)) (12.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from aiohttp->-r requirements.txt (line 1)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from aiohttp->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from aiohttp->-r requirements.txt (line 1)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from aiohttp->-r requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from aiohttp->-r requirements.txt (line 1)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from aiohttp->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from aiohttp->-r requirements.txt (line 1)) (1.22.0)
# Requirement already satisfied: idna>=2.0 in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp->-r requirements.txt (line 1)) (3.11)
# Requirement already satisfied: azure-core>=1.31.0 in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from azure-identity->-r requirements.txt (line 2)) (1.36.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from azure-identity->-r requirements.txt (line 2)) (46.0.3)
# Requirement already satisfied: msal>=1.30.0 in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from azure-identity->-r requirements.txt (line 2)) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from azure-identity->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from azure-identity->-r requirements.txt (line 2)) (4.15.0)
# Collecting isodate>=0.6.1 (from azure-storage-blob->-r requirements.txt (line 3))
#   Using cached isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from requests->-r requirements.txt (line 5)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from requests->-r requirements.txt (line 5)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from requests->-r requirements.txt (line 5)) (2025.11.12)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from cryptography>=2.5->azure-identity->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity->-r requirements.txt (line 2)) (2.23)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\zacharyzurlo\code\ai\remote-mcp-functions-python\.venv\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity->-r requirements.txt (line 2)) (2.10.1)
# Using cached azure_storage_blob-12.27.1-py3-none-any.whl (428 kB)
# Using cached isodate-0.7.2-py3-none-any.whl (22 kB)
# Installing collected packages: isodate, azure-storage-blob
#
#    ---------------------------------------- 0/2 [isodate]
#    ---------------------------------------- 0/2 [isodate]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    -------------------- ------------------- 1/2 [azure-storage-blob]
#    ---------------------------------------- 2/2 [azure-storage-blob]
#
# Successfully installed azure-storage-blob-12.27.1 isodate-0.7.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import logging
import json
import os
import sys
import uuid
from pathlib import Path
from dotenv import find_dotenv, load_dotenv
from azure.identity import DefaultAzureCredential, get_bearer_token_provider

load_dotenv(find_dotenv())
logging.basicConfig(level=logging.INFO)

# For authentication, you can use either token-based authentication or a subscription key; only one method is required.
AZURE_AI_ENDPOINT = os.getenv("CONTENT_UNDERSTANDING_ENDPOINT", "").strip()
AZURE_AI_API_KEY = os.getenv("CONTENT_UNDERSTANDING_API_KEY", "").strip()
AZURE_AI_API_VERSION = os.getenv("CONTENT_UNDERSTANDING_API_VERSION", "2025-05-01-preview").strip()

if not AZURE_AI_ENDPOINT:
    raise ValueError("Set CONTENT_UNDERSTANDING_ENDPOINT in your environment or .env file.")

# Add the parent directory to the path to use shared modules
parent_dir = Path(Path.cwd()).parent
sys.path.append(str(parent_dir))
from python.content_understanding_client import AzureContentUnderstandingClient

client_kwargs = {
    "endpoint": AZURE_AI_ENDPOINT,
    "api_version": AZURE_AI_API_VERSION or "2025-05-01-preview",
    "x_ms_useragent": "azure-ai-content-understanding-python/content_extraction",
}

if AZURE_AI_API_KEY:
    client_kwargs["subscription_key"] = AZURE_AI_API_KEY
else:
    credential = DefaultAzureCredential()
    token_provider = get_bearer_token_provider(credential, "https://cognitiveservices.azure.com/.default")
    client_kwargs["token_provider"] = token_provider

client = AzureContentUnderstandingClient(**client_kwargs)

# Utility function to save images
from PIL import Image
from io import BytesIO
import re

def save_image(image_id: str, response):
    raw_image = client.get_image_from_analyze_operation(analyze_response=response,
        image_id=image_id
    )
    image = Image.open(BytesIO(raw_image))
    # To display the image, uncomment the following line:
    # image.show()
    Path(".cache").mkdir(exist_ok=True)
    image.save(f".cache/{image_id}.jpg", "JPEG")
# Out:
# INFO:azure.identity._credentials.environment:No environment configuration found.
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.25.1 Python/3.12.10 (Windows-11-10.0.26200-SP0)'
# No body was attached to the request
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureCliCredential

# %%
INVOICE_IMAGE_PATH = '../data/invoice_sample.jpg'  # Replace with your uploaded invoice image
INVOICE_ANALYZER_ID = 'prebuilt-invoice'

invoice_image_file = Path(INVOICE_IMAGE_PATH)
if not invoice_image_file.exists():
    raise FileNotFoundError(f"Invoice image not found: {invoice_image_file}")

invoice_response = client.begin_analyze(INVOICE_ANALYZER_ID, file_location=str(invoice_image_file))
invoice_result = client.poll_result(invoice_response)

print(json.dumps(invoice_result, indent=2))
# Out:
# INFO:python.content_understanding_client:Analyzing file ..\data\invoice_sample.jpg with analyzer: prebuilt-invoice
# INFO:python.content_understanding_client:Request 7ca9d092-a423-48c1-8f0a-38746fd6a667 in progress ...
# INFO:python.content_understanding_client:Request 7ca9d092-a423-48c1-8f0a-38746fd6a667 in progress ...
# INFO:python.content_understanding_client:Request 7ca9d092-a423-48c1-8f0a-38746fd6a667 in progress ...
# INFO:python.content_understanding_client:Request result is ready after 9.24 seconds.
# {
#   "id": "7ca9d092-a423-48c1-8f0a-38746fd6a667",
#   "status": "Succeeded",
#   "result": {
#     "analyzerId": "prebuilt-invoice",
#     "apiVersion": "2025-05-01-preview",
#     "createdAt": "2025-12-04T21:40:41Z",
#     "warnings": [],
#     "contents": [
#       {
#         "markdown": "Contoso, Ltd.\n\n\n# Project Statement\n\nDate: 8/25/2020\n\nReceipt # No .: 3579\n\nSold To Bellows College\n892 Hemlock Street\nSpruce City, NY, 84112\nID#: 1234567\n\nLive Delivery:\n\u2610\n\nOnline Delivery (Livestream):\n\u2612\n\nVideo Delivery (On Demand):\n\n\u2610\n\n\n<table>\n<tr>\n<th>Training Date</th>\n<th>Description</th>\n<th>Price</th>\n<th>Discount</th>\n<th>Line Total</th>\n</tr>\n<tr>\n<td>10/12/2020</td>\n<td>Leadership Training</td>\n<td>$750</td>\n<td>10%</td>\n<td>$675</td>\n</tr>\n<tr>\n<td>10/13/2020</td>\n<td>Leadership Training</td>\n<td>$750</td>\n<td>10%</td>\n<td>$675</td>\n</tr>\n<tr>\n<td>10/14/2020</td>\n<td>Leadership Training</td>\n<td>$750</td>\n<td>10%</td>\n<td rowspan=\"2\">$675</td>\n</tr>\n<tr>\n<td></td>\n<td></td>\n<td></td>\n<td></td>\n</tr>\n</table>\n\n\n<table>\n<tr>\n<td>Subtotal</td>\n<td>$2,025</td>\n</tr>\n<tr>\n<td>Sales Tax</td>\n<td>-</td>\n</tr>\n<tr>\n<td>Total</td>\n<td>$2,025</td>\n</tr>\n</table>\n\n\nThank you for your business!\n",
#         "fields": {
#           "CustomerName": {
#             "type": "string",
#             "valueString": "Bellows College",
#             "spans": [
#               {
#                 "offset": 84,
#                 "length": 15
#               }
#             ],
#             "confidence": 0.534,
#             "source": "D(1,311.0198,233.8308,439.3728,236.0063,438.9971,258.1694,310.6442,255.9940)"
#           },
#           "InvoiceDate": {
#             "type": "date",
#             "valueDate": "2020-08-25",
#             "spans": [
#               {
#                 "offset": 43,
#                 "length": 9
#               }
#             ],
#             "confidence": 0.883,
#             "source": "D(1,1107.0000,157.0000,1191.0000,157.0000,1191.0000,178.0000,1107.0000,178.0000)"
#           },
#           "CustomerId": {
#             "type": "string",
#             "valueString": "1234567",
#             "spans": [
#               {
#                 "offset": 147,
#                 "length": 7
#               }
#             ],
#             "confidence": 0.594,
#             "source": "D(1,348.0000,362.0000,414.0000,362.0000,414.0000,380.0000,348.0000,380.0000)"
#           },
#           "PurchaseOrder": {
#             "type": "string",
#             "confidence": 0.741
#           },
#           "InvoiceId": {
#             "type": "string",
#             "valueString": "3579",
#             "spans": [
#               {
#                 "offset": 70,
#                 "length": 4
#               }
#             ],
#             "confidence": 0.867,
#             "source": "D(1,1141.0000,185.0000,1189.0000,184.0000,1189.0000,207.0000,1141.0000,207.0000)"
#           },
#           "DueDate": {
#             "type": "date",
#             "confidence": 0.856
#           },
#           "VendorName": {
#             "type": "string",
#             "valueString": "Contoso, Ltd.",
#             "spans": [
#               {
#                 "offset": 0,
#                 "length": 13
#               }
#             ],
#             "confidence": 0.826,
#             "source": "D(1,85.0000,62.0000,353.0000,62.0000,353.0000,121.0000,85.0000,121.0000)"
#           },
#           "VendorAddress": {
#             "type": "string",
#             "confidence": 0.717
#           },
#           "VendorAddressRecipient": {
#             "type": "string",
#             "confidence": 0.768
#           },
#           "CustomerAddress": {
#             "type": "string",
#             "valueString": "892 Hemlock Street\nSpruce City, NY, 84112",
#             "spans": [
#               {
#                 "offset": 100,
#                 "length": 18
#               },
#               {
#                 "offset": 119,
#                 "length": 22
#               }
#             ],
#             "confidence": 0.789,
#             "source": "D(1,310.0000,286.0000,468.0000,286.0000,468.0000,306.0000,310.0000,306.0000);D(1,310.0000,311.0000,493.0000,311.0000,493.0000,332.0000,310.0000,332.0000)"
#           },
#           "CustomerAddressRecipient": {
#             "type": "string",
#             "valueString": "Sold To Bellows College",
#             "spans": [
#               {
#                 "offset": 76,
#                 "length": 23
#               }
#             ],
#             "confidence": 0.434,
#             "source": "D(1,212.0313,232.1531,439.3728,236.0063,438.9687,259.8469,211.6272,255.9937)"
#           },
#           "BillingAddress": {
#             "type": "string",
#             "confidence": 0.945
#           },
#           "BillingAddressRecipient": {
#             "type": "string",
#             "confidence": 0.938
#           },
#           "ShippingAddress": {
#             "type": "string",
#             "confidence": 0.983
#           },
#           "ShippingAddressRecipient": {
#             "type": "string",
#             "confidence": 0.978
#           },
#           "SubTotal": {
#             "type": "number",
#             "valueNumber": 2025,
#             "spans": [
#               {
#                 "offset": 768,
#                 "length": 6
#               }
#             ],
#             "confidence": 0.691,
#             "source": "D(1,1034.0000,943.0000,1103.0000,943.0000,1103.0000,965.0000,1034.0000,966.0000)"
#           },
#           "TotalDiscount": {
#             "type": "number",
#             "confidence": 0.95
#           },
#           "TotalTax": {
#             "type": "number",
#             "spans": [
#               {
#                 "offset": 814,
#                 "length": 1
#               }
#             ],
#             "confidence": 0.476,
#             "source": "D(1,1035.0000,992.0000,1044.0000,992.0000,1044.0000,1000.0000,1035.0000,1001.0000)"
#           },
#           "InvoiceTotal": {
#             "type": "number",
#             "valueNumber": 2025,
#             "spans": [
#               {
#                 "offset": 851,
#                 "length": 6
#               }
#             ],
#             "confidence": 0.874,
#             "source": "D(1,1034.0000,1024.0000,1103.0000,1024.0000,1103.0000,1046.0000,1034.0000,1046.0000)"
#           },
#           "AmountDue": {
#             "type": "number",
#             "valueNumber": 2025,
#             "spans": [
#               {
#                 "offset": 851,
#                 "length": 6
#               }
#             ],
#             "confidence": 0.874,
#             "source": "D(1,1034.0000,1024.0000,1103.0000,1024.0000,1103.0000,1046.0000,1034.0000,1046.0000)"
#           },
#           "PreviousUnpaidBalance": {
#             "type": "number",
#             "confidence": 0.986
#           },
#           "RemittanceAddress": {
#             "type": "string",
#             "confidence": 0.911
#           },
#           "RemittanceAddressRecipient": {
#             "type": "string",
#             "confidence": 0.862
#           },
#           "ServiceAddress": {
#             "type": "string",
#             "confidence": 0.979
#           },
#           "ServiceAddressRecipient": {
#             "type": "string",
#             "confidence": 0.952
#           },
#           "VendorTaxId": {
#             "type": "string",
#             "confidence": 0.952
#           },
#           "CustomerTaxId": {
#             "type": "string",
#             "confidence": 0.922
#           },
#           "PaymentTerm": {
#             "type": "string",
#             "confidence": 0.833
#           },
#           "TaxDetails": {
#             "type": "array"
#           },
#           "Items": {
#             "type": "array",
#             "valueArray": [
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "TotalPrice": {
#                     "type": "number",
#                     "valueNumber": 675,
#                     "spans": [
#                       {
#                         "offset": 441,
#                         "length": 4
#                       }
#                     ],
#                     "confidence": 0.611,
#                     "source": "D(1,1085.0000,676.0000,1124.0000,676.0000,1124.0000,693.0000,1085.0000,694.0000)"
#                   },
#                   "Date": {
#                     "type": "date",
#                     "valueDate": "2020-10-12",
#                     "spans": [
#                       {
#                         "offset": 365,
#                         "length": 10
#                       }
#                     ],
#                     "confidence": 0.884,
#                     "source": "D(1,125.0000,675.0000,216.0000,675.0000,216.0000,695.0000,125.0000,695.0000)"
#                   },
#                   "Description": {
#                     "type": "string",
#                     "valueString": "Leadership Training",
#                     "spans": [
#                       {
#                         "offset": 385,
#                         "length": 19
#                       }
#                     ],
#                     "confidence": 0.971,
#                     "source": "D(1,372.0057,674.2735,529.1601,675.5013,528.9958,696.5312,371.8414,695.3034)"
#                   },
#                   "Quantity": {
#                     "type": "number",
#                     "confidence": 0.765
#                   },
#                   "ProductCode": {
#                     "type": "string",
#                     "confidence": 0.912
#                   },
#                   "TaxAmount": {
#                     "type": "number",
#                     "confidence": 0.805
#                   },
#                   "TaxRate": {
#                     "type": "number",
#                     "confidence": 0.777
#                   },
#                   "Unit": {
#                     "type": "string",
#                     "confidence": 0.701
#                   },
#                   "UnitPrice": {
#                     "type": "number",
#                     "valueNumber": 750,
#                     "spans": [
#                       {
#                         "offset": 414,
#                         "length": 4
#                       }
#                     ],
#                     "confidence": 0.671,
#                     "source": "D(1,711.0000,676.0000,750.0000,676.0000,750.0000,694.0000,711.0000,694.0000)"
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "TotalPrice": {
#                     "type": "number",
#                     "valueNumber": 675,
#                     "spans": [
#                       {
#                         "offset": 542,
#                         "length": 4
#                       }
#                     ],
#                     "confidence": 0.94,
#                     "source": "D(1,1086.0000,708.0000,1124.0000,708.0000,1124.0000,726.0000,1086.0000,726.0000)"
#                   },
#                   "Date": {
#                     "type": "date",
#                     "valueDate": "2020-10-13",
#                     "spans": [
#                       {
#                         "offset": 466,
#                         "length": 10
#                       }
#                     ],
#                     "confidence": 0.941,
#                     "source": "D(1,125.0000,707.0000,216.0000,707.0000,216.0000,727.0000,125.0000,727.0000)"
#                   },
#                   "Description": {
#                     "type": "string",
#                     "valueString": "Leadership Training",
#                     "spans": [
#                       {
#                         "offset": 486,
#                         "length": 19
#                       }
#                     ],
#                     "confidence": 0.971,
#                     "source": "D(1,372.0058,706.2599,529.1614,707.4973,528.9957,728.5433,371.8401,727.3058)"
#                   },
#                   "Quantity": {
#                     "type": "number",
#                     "confidence": 0.981
#                   },
#                   "ProductCode": {
#                     "type": "string",
#                     "confidence": 0.978
#                   },
#                   "TaxAmount": {
#                     "type": "number",
#                     "confidence": 0.974
#                   },
#                   "TaxRate": {
#                     "type": "number",
#                     "confidence": 0.95
#                   },
#                   "Unit": {
#                     "type": "string",
#                     "confidence": 0.943
#                   },
#                   "UnitPrice": {
#                     "type": "number",
#                     "valueNumber": 750,
#                     "spans": [
#                       {
#                         "offset": 515,
#                         "length": 4
#                       }
#                     ],
#                     "confidence": 0.901,
#                     "source": "D(1,711.0000,708.0000,750.0000,708.0000,750.0000,726.0000,711.0000,726.0000)"
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "TotalPrice": {
#                     "type": "number",
#                     "valueNumber": 675,
#                     "spans": [
#                       {
#                         "offset": 655,
#                         "length": 4
#                       }
#                     ],
#                     "confidence": 0.906,
#                     "source": "D(1,1086.0000,741.0000,1124.0000,741.0000,1124.0000,759.0000,1085.0000,759.0000)"
#                   },
#                   "Date": {
#                     "type": "date",
#                     "valueDate": "2020-10-14",
#                     "spans": [
#                       {
#                         "offset": 567,
#                         "length": 10
#                       }
#                     ],
#                     "confidence": 0.933,
#                     "source": "D(1,125.0000,740.0000,216.0000,741.0000,216.0000,760.0000,125.0000,760.0000)"
#                   },
#                   "Description": {
#                     "type": "string",
#                     "valueString": "Leadership Training",
#                     "spans": [
#                       {
#                         "offset": 587,
#                         "length": 19
#                       }
#                     ],
#                     "confidence": 0.965,
#                     "source": "D(1,372.0086,739.2361,529.2359,741.0027,529.0000,762.0000,371.7727,760.2334)"
#                   },
#                   "Quantity": {
#                     "type": "number",
#                     "confidence": 0.938
#                   },
#                   "ProductCode": {
#                     "type": "string",
#                     "confidence": 0.971
#                   },
#                   "TaxAmount": {
#                     "type": "number",
#                     "confidence": 0.974
#                   },
#                   "TaxRate": {
#                     "type": "number",
#                     "confidence": 0.941
#                   },
#                   "Unit": {
#                     "type": "string",
#                     "confidence": 0.935
#                   },
#                   "UnitPrice": {
#                     "type": "number",
#                     "valueNumber": 750,
#                     "spans": [
#                       {
#                         "offset": 616,
#                         "length": 4
#                       }
#                     ],
#                     "confidence": 0.906,
#                     "source": "D(1,711.0000,741.0000,750.0000,741.0000,750.0000,759.0000,711.0000,759.0000)"
#                   }
#                 }
#               }
#             ]
#           }
#         },
#         "kind": "document",
#         "startPageNumber": 1,
#         "endPageNumber": 1,
#         "unit": "pixel",
#         "pages": [
#           {
#             "pageNumber": 1,
#             "angle": 0.1205968,
#             "width": 1275,
#             "height": 1650,
#             "spans": [
#               {
#                 "offset": 0,
#                 "length": 909
#               }
#             ],
#             "words": [
#               {
#                 "content": "Contoso,",
#                 "span": {
#                   "offset": 0,
#                   "length": 8
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,85,64,262,62,262,121,85,121)"
#               },
#               {
#                 "content": "Ltd.",
#                 "span": {
#                   "offset": 9,
#                   "length": 4
#                 },
#                 "confidence": 0.991,
#                 "source": "D(1,276,63,353,63,353,121,276,121)"
#               },
#               {
#                 "content": "Project",
#                 "span": {
#                   "offset": 18,
#                   "length": 7
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,753,50,934,50,934,106,753,105)"
#               },
#               {
#                 "content": "Statement",
#                 "span": {
#                   "offset": 26,
#                   "length": 9
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,950,50,1218,50,1218,102,950,106)"
#               },
#               {
#                 "content": "Date:",
#                 "span": {
#                   "offset": 37,
#                   "length": 5
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,1045,156,1100,157,1100,178,1045,178)"
#               },
#               {
#                 "content": "8/25/2020",
#                 "span": {
#                   "offset": 43,
#                   "length": 9
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,1107,157,1191,157,1191,178,1107,178)"
#               },
#               {
#                 "content": "Receipt",
#                 "span": {
#                   "offset": 54,
#                   "length": 7
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,986,185,1067,185,1067,208,986,208)"
#               },
#               {
#                 "content": "#",
#                 "span": {
#                   "offset": 62,
#                   "length": 1
#                 },
#                 "confidence": 0.989,
#                 "source": "D(1,1074,185,1086,185,1086,208,1074,208)"
#               },
#               {
#                 "content": "No",
#                 "span": {
#                   "offset": 64,
#                   "length": 2
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,1094,185,1115,185,1115,207,1094,208)"
#               },
#               {
#                 "content": ".:",
#                 "span": {
#                   "offset": 67,
#                   "length": 2
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,1120,185,1134,185,1134,207,1120,207)"
#               },
#               {
#                 "content": "3579",
#                 "span": {
#                   "offset": 70,
#                   "length": 4
#                 },
#                 "confidence": 0.989,
#                 "source": "D(1,1141,185,1189,184,1189,207,1141,207)"
#               },
#               {
#                 "content": "Sold",
#                 "span": {
#                   "offset": 76,
#                   "length": 4
#                 },
#                 "confidence": 0.989,
#                 "source": "D(1,212,234,257,234,257,256,212,256)"
#               },
#               {
#                 "content": "To",
#                 "span": {
#                   "offset": 81,
#                   "length": 2
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,263,234,287,234,287,257,263,256)"
#               },
#               {
#                 "content": "Bellows",
#                 "span": {
#                   "offset": 84,
#                   "length": 7
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,311,235,370,236,370,257,311,256)"
#               },
#               {
#                 "content": "College",
#                 "span": {
#                   "offset": 92,
#                   "length": 7
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,375,236,439,236,439,258,375,257)"
#               },
#               {
#                 "content": "892",
#                 "span": {
#                   "offset": 100,
#                   "length": 3
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,310,286,338,286,338,305,310,305)"
#               },
#               {
#                 "content": "Hemlock",
#                 "span": {
#                   "offset": 104,
#                   "length": 7
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,345,286,417,286,417,305,345,305)"
#               },
#               {
#                 "content": "Street",
#                 "span": {
#                   "offset": 112,
#                   "length": 6
#                 },
#                 "confidence": 0.993,
#                 "source": "D(1,421,286,468,286,468,305,421,306)"
#               },
#               {
#                 "content": "Spruce",
#                 "span": {
#                   "offset": 119,
#                   "length": 6
#                 },
#                 "confidence": 0.993,
#                 "source": "D(1,310,312,366,312,366,332,310,332)"
#               },
#               {
#                 "content": "City,",
#                 "span": {
#                   "offset": 126,
#                   "length": 5
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,372,312,407,312,407,331,372,332)"
#               },
#               {
#                 "content": "NY,",
#                 "span": {
#                   "offset": 132,
#                   "length": 3
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,413,312,439,312,439,331,413,331)"
#               },
#               {
#                 "content": "84112",
#                 "span": {
#                   "offset": 136,
#                   "length": 5
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,445,311,493,311,493,331,445,331)"
#               },
#               {
#                 "content": "ID#:",
#                 "span": {
#                   "offset": 142,
#                   "length": 4
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,311,362,341,362,341,380,310,380)"
#               },
#               {
#                 "content": "1234567",
#                 "span": {
#                   "offset": 147,
#                   "length": 7
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,348,362,414,362,414,380,348,380)"
#               },
#               {
#                 "content": "Live",
#                 "span": {
#                   "offset": 156,
#                   "length": 4
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,75,564,114,564,114,587,75,586)"
#               },
#               {
#                 "content": "Delivery:",
#                 "span": {
#                   "offset": 161,
#                   "length": 9
#                 },
#                 "confidence": 0.993,
#                 "source": "D(1,121,564,209,565,209,587,121,587)"
#               },
#               {
#                 "content": "\u2610",
#                 "span": {
#                   "offset": 171,
#                   "length": 1
#                 },
#                 "confidence": 0.986,
#                 "source": "D(1,216,563,243,563,243,590,216,590)"
#               },
#               {
#                 "content": "Online",
#                 "span": {
#                   "offset": 174,
#                   "length": 6
#                 },
#                 "confidence": 0.998,
#                 "source": "D(1,300,563,365,564,365,588,300,587)"
#               },
#               {
#                 "content": "Delivery",
#                 "span": {
#                   "offset": 181,
#                   "length": 8
#                 },
#                 "confidence": 0.997,
#                 "source": "D(1,372,564,453,564,453,588,372,588)"
#               },
#               {
#                 "content": "(Livestream):",
#                 "span": {
#                   "offset": 190,
#                   "length": 13
#                 },
#                 "confidence": 0.993,
#                 "source": "D(1,459,564,589,564,589,589,459,588)"
#               },
#               {
#                 "content": "\u2612",
#                 "span": {
#                   "offset": 204,
#                   "length": 1
#                 },
#                 "confidence": 0.989,
#                 "source": "D(1,597,563,625,563,625,590,597,590)"
#               },
#               {
#                 "content": "Video",
#                 "span": {
#                   "offset": 207,
#                   "length": 5
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,674,563,734,563,734,588,674,587)"
#               },
#               {
#                 "content": "Delivery",
#                 "span": {
#                   "offset": 213,
#                   "length": 8
#                 },
#                 "confidence": 0.997,
#                 "source": "D(1,742,563,822,563,822,588,742,588)"
#               },
#               {
#                 "content": "(On",
#                 "span": {
#                   "offset": 222,
#                   "length": 3
#                 },
#                 "confidence": 0.997,
#                 "source": "D(1,828,564,864,564,864,588,828,588)"
#               },
#               {
#                 "content": "Demand):",
#                 "span": {
#                   "offset": 226,
#                   "length": 8
#                 },
#                 "confidence": 0.993,
#                 "source": "D(1,873,564,974,564,974,589,873,588)"
#               },
#               {
#                 "content": "\u2610",
#                 "span": {
#                   "offset": 236,
#                   "length": 1
#                 },
#                 "confidence": 0.983,
#                 "source": "D(1,980,563,1007,563,1007,590,980,591)"
#               },
#               {
#                 "content": "Training",
#                 "span": {
#                   "offset": 257,
#                   "length": 8
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,103,639,181,639,181,662,103,662)"
#               },
#               {
#                 "content": "Date",
#                 "span": {
#                   "offset": 266,
#                   "length": 4
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,189,639,236,639,236,662,189,662)"
#               },
#               {
#                 "content": "Description",
#                 "span": {
#                   "offset": 280,
#                   "length": 11
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,394,639,507,639,507,663,394,662)"
#               },
#               {
#                 "content": "Price",
#                 "span": {
#                   "offset": 301,
#                   "length": 5
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,706,640,757,640,757,660,706,659)"
#               },
#               {
#                 "content": "Discount",
#                 "span": {
#                   "offset": 316,
#                   "length": 8
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,874,639,963,640,963,660,874,660)"
#               },
#               {
#                 "content": "Line",
#                 "span": {
#                   "offset": 334,
#                   "length": 4
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,1059,639,1098,639,1098,660,1059,660)"
#               },
#               {
#                 "content": "Total",
#                 "span": {
#                   "offset": 339,
#                   "length": 5
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,1103,639,1152,639,1152,660,1103,660)"
#               },
#               {
#                 "content": "10/12/2020",
#                 "span": {
#                   "offset": 365,
#                   "length": 10
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,125,675,216,675,216,695,125,695)"
#               },
#               {
#                 "content": "Leadership",
#                 "span": {
#                   "offset": 385,
#                   "length": 10
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,372,675,461,675,461,696,372,695)"
#               },
#               {
#                 "content": "Training",
#                 "span": {
#                   "offset": 396,
#                   "length": 8
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,465,675,529,676,529,696,465,696)"
#               },
#               {
#                 "content": "$750",
#                 "span": {
#                   "offset": 414,
#                   "length": 4
#                 },
#                 "confidence": 0.977,
#                 "source": "D(1,711,676,750,676,750,694,711,694)"
#               },
#               {
#                 "content": "10%",
#                 "span": {
#                   "offset": 428,
#                   "length": 3
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,902,676,935,676,935,693,902,693)"
#               },
#               {
#                 "content": "$675",
#                 "span": {
#                   "offset": 441,
#                   "length": 4
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,1085,676,1124,676,1124,693,1085,694)"
#               },
#               {
#                 "content": "10/13/2020",
#                 "span": {
#                   "offset": 466,
#                   "length": 10
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,125,707,216,707,216,727,125,727)"
#               },
#               {
#                 "content": "Leadership",
#                 "span": {
#                   "offset": 486,
#                   "length": 10
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,372,707,460,707,460,728,372,727)"
#               },
#               {
#                 "content": "Training",
#                 "span": {
#                   "offset": 497,
#                   "length": 8
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,466,707,529,708,529,728,465,728)"
#               },
#               {
#                 "content": "$750",
#                 "span": {
#                   "offset": 515,
#                   "length": 4
#                 },
#                 "confidence": 0.982,
#                 "source": "D(1,711,708,750,708,750,726,711,726)"
#               },
#               {
#                 "content": "10%",
#                 "span": {
#                   "offset": 529,
#                   "length": 3
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,903,708,935,708,935,725,903,725)"
#               },
#               {
#                 "content": "$675",
#                 "span": {
#                   "offset": 542,
#                   "length": 4
#                 },
#                 "confidence": 0.977,
#                 "source": "D(1,1086,708,1124,708,1124,726,1086,726)"
#               },
#               {
#                 "content": "10/14/2020",
#                 "span": {
#                   "offset": 567,
#                   "length": 10
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,125,740,216,741,216,760,125,760)"
#               },
#               {
#                 "content": "Leadership",
#                 "span": {
#                   "offset": 587,
#                   "length": 10
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,372,740,461,741,461,761,372,760)"
#               },
#               {
#                 "content": "Training",
#                 "span": {
#                   "offset": 598,
#                   "length": 8
#                 },
#                 "confidence": 0.997,
#                 "source": "D(1,465,741,529,741,529,762,465,761)"
#               },
#               {
#                 "content": "$750",
#                 "span": {
#                   "offset": 616,
#                   "length": 4
#                 },
#                 "confidence": 0.989,
#                 "source": "D(1,711,741,750,741,750,759,711,759)"
#               },
#               {
#                 "content": "10%",
#                 "span": {
#                   "offset": 630,
#                   "length": 3
#                 },
#                 "confidence": 0.989,
#                 "source": "D(1,903,741,935,741,935,758,903,758)"
#               },
#               {
#                 "content": "$675",
#                 "span": {
#                   "offset": 655,
#                   "length": 4
#                 },
#                 "confidence": 0.977,
#                 "source": "D(1,1086,741,1124,741,1124,759,1085,759)"
#               },
#               {
#                 "content": "Subtotal",
#                 "span": {
#                   "offset": 750,
#                   "length": 8
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,838,943,924,943,924,964,838,964)"
#               },
#               {
#                 "content": "$2,025",
#                 "span": {
#                   "offset": 768,
#                   "length": 6
#                 },
#                 "confidence": 0.989,
#                 "source": "D(1,1034,943,1103,943,1103,965,1034,966)"
#               },
#               {
#                 "content": "Sales",
#                 "span": {
#                   "offset": 795,
#                   "length": 5
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,838,984,892,985,892,1005,838,1005)"
#               },
#               {
#                 "content": "Tax",
#                 "span": {
#                   "offset": 801,
#                   "length": 3
#                 },
#                 "confidence": 0.997,
#                 "source": "D(1,898,985,935,985,935,1005,898,1005)"
#               },
#               {
#                 "content": "-",
#                 "span": {
#                   "offset": 814,
#                   "length": 1
#                 },
#                 "confidence": 0.683,
#                 "source": "D(1,1035,992,1044,992,1044,1000,1035,1001)"
#               },
#               {
#                 "content": "Total",
#                 "span": {
#                   "offset": 836,
#                   "length": 5
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,837,1024,888,1024,888,1045,837,1045)"
#               },
#               {
#                 "content": "$2,025",
#                 "span": {
#                   "offset": 851,
#                   "length": 6
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,1034,1024,1103,1024,1103,1046,1034,1046)"
#               },
#               {
#                 "content": "Thank",
#                 "span": {
#                   "offset": 880,
#                   "length": 5
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,495,1172,556,1173,556,1196,495,1196)"
#               },
#               {
#                 "content": "you",
#                 "span": {
#                   "offset": 886,
#                   "length": 3
#                 },
#                 "confidence": 0.999,
#                 "source": "D(1,562,1173,598,1173,598,1196,561,1196)"
#               },
#               {
#                 "content": "for",
#                 "span": {
#                   "offset": 890,
#                   "length": 3
#                 },
#                 "confidence": 0.999,
#                 "source": "D(1,604,1173,631,1173,631,1196,604,1196)"
#               },
#               {
#                 "content": "your",
#                 "span": {
#                   "offset": 894,
#                   "length": 4
#                 },
#                 "confidence": 0.989,
#                 "source": "D(1,637,1173,682,1173,682,1196,636,1196)"
#               },
#               {
#                 "content": "business!",
#                 "span": {
#                   "offset": 899,
#                   "length": 9
#                 },
#                 "confidence": 0.977,
#                 "source": "D(1,687,1173,780,1173,780,1196,687,1196)"
#               }
#             ],
#             "lines": [
#               {
#                 "content": "Contoso, Ltd.",
#                 "source": "D(1,84,63,353,62,353,120,85,121)",
#                 "span": {
#                   "offset": 0,
#                   "length": 13
#                 }
#               },
#               {
#                 "content": "Project Statement",
#                 "source": "D(1,753,50,1217,49,1217,104,753,106)",
#                 "span": {
#                   "offset": 18,
#                   "length": 17
#                 }
#               },
#               {
#                 "content": "Date: 8/25/2020",
#                 "source": "D(1,1045,156,1190,157,1190,178,1045,178)",
#                 "span": {
#                   "offset": 37,
#                   "length": 15
#                 }
#               },
#               {
#                 "content": "Receipt # No .: 3579",
#                 "source": "D(1,986,185,1189,184,1189,207,986,208)",
#                 "span": {
#                   "offset": 54,
#                   "length": 20
#                 }
#               },
#               {
#                 "content": "Sold To Bellows College",
#                 "source": "D(1,212,233,439,235,439,257,212,256)",
#                 "span": {
#                   "offset": 76,
#                   "length": 23
#                 }
#               },
#               {
#                 "content": "892 Hemlock Street",
#                 "source": "D(1,310,286,467,286,467,305,310,305)",
#                 "span": {
#                   "offset": 100,
#                   "length": 18
#                 }
#               },
#               {
#                 "content": "Spruce City, NY, 84112",
#                 "source": "D(1,310,312,492,311,493,331,310,332)",
#                 "span": {
#                   "offset": 119,
#                   "length": 22
#                 }
#               },
#               {
#                 "content": "ID#: 1234567",
#                 "source": "D(1,310,362,413,362,413,379,310,380)",
#                 "span": {
#                   "offset": 142,
#                   "length": 12
#                 }
#               },
#               {
#                 "content": "Live Delivery:",
#                 "source": "D(1,75,564,208,565,208,587,75,586)",
#                 "span": {
#                   "offset": 156,
#                   "length": 14
#                 }
#               },
#               {
#                 "content": "\u2610",
#                 "source": "D(1,216,563,243,563,243,590,216,590)",
#                 "span": {
#                   "offset": 171,
#                   "length": 1
#                 }
#               },
#               {
#                 "content": "Online Delivery (Livestream):",
#                 "source": "D(1,300,563,589,564,589,588,300,588)",
#                 "span": {
#                   "offset": 174,
#                   "length": 29
#                 }
#               },
#               {
#                 "content": "\u2612",
#                 "source": "D(1,597,563,625,563,625,590,597,590)",
#                 "span": {
#                   "offset": 204,
#                   "length": 1
#                 }
#               },
#               {
#                 "content": "Video Delivery (On Demand):",
#                 "source": "D(1,674,563,973,564,973,588,674,588)",
#                 "span": {
#                   "offset": 207,
#                   "length": 27
#                 }
#               },
#               {
#                 "content": "\u2610",
#                 "source": "D(1,980,563,1007,563,1007,590,980,591)",
#                 "span": {
#                   "offset": 236,
#                   "length": 1
#                 }
#               },
#               {
#                 "content": "Training Date",
#                 "source": "D(1,103,639,236,639,236,662,103,662)",
#                 "span": {
#                   "offset": 257,
#                   "length": 13
#                 }
#               },
#               {
#                 "content": "Description",
#                 "source": "D(1,394,639,507,639,507,662,394,662)",
#                 "span": {
#                   "offset": 280,
#                   "length": 11
#                 }
#               },
#               {
#                 "content": "Price",
#                 "source": "D(1,706,640,756,640,756,660,706,659)",
#                 "span": {
#                   "offset": 301,
#                   "length": 5
#                 }
#               },
#               {
#                 "content": "Discount",
#                 "source": "D(1,874,639,962,639,962,660,874,660)",
#                 "span": {
#                   "offset": 316,
#                   "length": 8
#                 }
#               },
#               {
#                 "content": "Line Total",
#                 "source": "D(1,1059,639,1151,639,1151,660,1059,660)",
#                 "span": {
#                   "offset": 334,
#                   "length": 10
#                 }
#               },
#               {
#                 "content": "10/12/2020",
#                 "source": "D(1,125,675,216,675,216,695,125,695)",
#                 "span": {
#                   "offset": 365,
#                   "length": 10
#                 }
#               },
#               {
#                 "content": "Leadership Training",
#                 "source": "D(1,372,675,529,676,528,696,372,695)",
#                 "span": {
#                   "offset": 385,
#                   "length": 19
#                 }
#               },
#               {
#                 "content": "$750",
#                 "source": "D(1,711,676,750,676,750,694,711,694)",
#                 "span": {
#                   "offset": 414,
#                   "length": 4
#                 }
#               },
#               {
#                 "content": "10%",
#                 "source": "D(1,902,676,935,676,935,693,902,693)",
#                 "span": {
#                   "offset": 428,
#                   "length": 3
#                 }
#               },
#               {
#                 "content": "$675",
#                 "source": "D(1,1085,676,1124,676,1124,693,1085,693)",
#                 "span": {
#                   "offset": 441,
#                   "length": 4
#                 }
#               },
#               {
#                 "content": "10/13/2020",
#                 "source": "D(1,125,707,216,707,216,727,125,727)",
#                 "span": {
#                   "offset": 466,
#                   "length": 10
#                 }
#               },
#               {
#                 "content": "Leadership Training",
#                 "source": "D(1,372,707,529,708,529,728,372,728)",
#                 "span": {
#                   "offset": 486,
#                   "length": 19
#                 }
#               },
#               {
#                 "content": "$750",
#                 "source": "D(1,711,708,749,708,749,726,711,726)",
#                 "span": {
#                   "offset": 515,
#                   "length": 4
#                 }
#               },
#               {
#                 "content": "10%",
#                 "source": "D(1,903,708,935,708,935,725,903,725)",
#                 "span": {
#                   "offset": 529,
#                   "length": 3
#                 }
#               },
#               {
#                 "content": "$675",
#                 "source": "D(1,1085,708,1124,708,1124,726,1086,726)",
#                 "span": {
#                   "offset": 542,
#                   "length": 4
#                 }
#               },
#               {
#                 "content": "10/14/2020",
#                 "source": "D(1,125,740,216,741,216,760,125,759)",
#                 "span": {
#                   "offset": 567,
#                   "length": 10
#                 }
#               },
#               {
#                 "content": "Leadership Training",
#                 "source": "D(1,372,740,529,741,529,761,372,761)",
#                 "span": {
#                   "offset": 587,
#                   "length": 19
#                 }
#               },
#               {
#                 "content": "$750",
#                 "source": "D(1,711,741,750,741,749,759,711,759)",
#                 "span": {
#                   "offset": 616,
#                   "length": 4
#                 }
#               },
#               {
#                 "content": "10%",
#                 "source": "D(1,903,741,935,741,935,758,902,758)",
#                 "span": {
#                   "offset": 630,
#                   "length": 3
#                 }
#               },
#               {
#                 "content": "$675",
#                 "source": "D(1,1086,741,1124,741,1124,759,1085,759)",
#                 "span": {
#                   "offset": 655,
#                   "length": 4
#                 }
#               },
#               {
#                 "content": "Subtotal",
#                 "source": "D(1,838,943,924,943,924,964,838,964)",
#                 "span": {
#                   "offset": 750,
#                   "length": 8
#                 }
#               },
#               {
#                 "content": "$2,025",
#                 "source": "D(1,1034,943,1102,943,1102,965,1034,966)",
#                 "span": {
#                   "offset": 768,
#                   "length": 6
#                 }
#               },
#               {
#                 "content": "Sales Tax",
#                 "source": "D(1,838,984,935,985,935,1005,838,1005)",
#                 "span": {
#                   "offset": 795,
#                   "length": 9
#                 }
#               },
#               {
#                 "content": "-",
#                 "source": "D(1,1035,992,1044,992,1044,1000,1035,1000)",
#                 "span": {
#                   "offset": 814,
#                   "length": 1
#                 }
#               },
#               {
#                 "content": "Total",
#                 "source": "D(1,837,1024,888,1024,888,1045,837,1045)",
#                 "span": {
#                   "offset": 836,
#                   "length": 5
#                 }
#               },
#               {
#                 "content": "$2,025",
#                 "source": "D(1,1034,1024,1102,1024,1102,1046,1034,1046)",
#                 "span": {
#                   "offset": 851,
#                   "length": 6
#                 }
#               },
#               {
#                 "content": "Thank you for your business!",
#                 "source": "D(1,495,1172,779,1173,779,1196,495,1196)",
#                 "span": {
#                   "offset": 880,
#                   "length": 28
#                 }
#               }
#             ]
#           }
#         ],
#         "paragraphs": [
#           {
#             "content": "Contoso, Ltd.",
#             "source": "D(1,84,63,353,62,353,120,85,121)",
#             "span": {
#               "offset": 0,
#               "length": 13
#             }
#           },
#           {
#             "role": "title",
#             "content": "Project Statement",
#             "source": "D(1,753,50,1217,49,1217,104,753,106)",
#             "span": {
#               "offset": 16,
#               "length": 19
#             }
#           },
#           {
#             "content": "Date: 8/25/2020",
#             "source": "D(1,1045,156,1190,157,1190,178,1045,178)",
#             "span": {
#               "offset": 37,
#               "length": 15
#             }
#           },
#           {
# ...
#               "/sections/1",
#               "/sections/2"
#             ]
#           },
#           {
#             "span": {
#               "offset": 0,
#               "length": 13
#             },
#             "elements": [
#               "/paragraphs/0"
#             ]
#           },
#           {
#             "span": {
#               "offset": 16,
#               "length": 892
#             },
#             "elements": [
#               "/paragraphs/1",
#               "/paragraphs/2",
#               "/paragraphs/3",
#               "/paragraphs/4",
#               "/paragraphs/5",
#               "/paragraphs/6",
#               "/paragraphs/7",
#               "/paragraphs/8",
#               "/tables/0",
#               "/tables/1",
#               "/paragraphs/35"
#             ]
#           }
#         ],
#         "tables": [
#           {
#             "rowCount": 5,
#             "columnCount": 5,
#             "cells": [
#               {
#                 "kind": "columnHeader",
#                 "rowIndex": 0,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "Training Date",
#                 "source": "D(1,77,631,264,631,264,665,77,665)",
#                 "span": {
#                   "offset": 257,
#                   "length": 13
#                 },
#                 "elements": [
#                   "/paragraphs/9"
#                 ]
#               },
#               {
#                 "kind": "columnHeader",
#                 "rowIndex": 0,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "Description",
#                 "source": "D(1,264,631,637,630,637,665,264,665)",
#                 "span": {
#                   "offset": 280,
#                   "length": 11
#                 },
#                 "elements": [
#                   "/paragraphs/10"
#                 ]
#               },
#               {
#                 "kind": "columnHeader",
#                 "rowIndex": 0,
#                 "columnIndex": 2,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "Price",
#                 "source": "D(1,637,630,823,630,823,665,637,665)",
#                 "span": {
#                   "offset": 301,
#                   "length": 5
#                 },
#                 "elements": [
#                   "/paragraphs/11"
#                 ]
#               },
#               {
#                 "kind": "columnHeader",
#                 "rowIndex": 0,
#                 "columnIndex": 3,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "Discount",
#                 "source": "D(1,823,630,1010,630,1011,665,823,665)",
#                 "span": {
#                   "offset": 316,
#                   "length": 8
#                 },
#                 "elements": [
#                   "/paragraphs/12"
#                 ]
#               },
#               {
#                 "kind": "columnHeader",
#                 "rowIndex": 0,
#                 "columnIndex": 4,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "Line Total",
#                 "source": "D(1,1010,630,1196,630,1196,665,1011,665)",
#                 "span": {
#                   "offset": 334,
#                   "length": 10
#                 },
#                 "elements": [
#                   "/paragraphs/13"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 1,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "10/12/2020",
#                 "source": "D(1,77,665,264,665,264,700,76,700)",
#                 "span": {
#                   "offset": 365,
#                   "length": 10
#                 },
#                 "elements": [
#                   "/paragraphs/14"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 1,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "Leadership Training",
#                 "source": "D(1,264,665,637,665,637,700,264,700)",
#                 "span": {
#                   "offset": 385,
#                   "length": 19
#                 },
#                 "elements": [
#                   "/paragraphs/15"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 1,
#                 "columnIndex": 2,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$750",
#                 "source": "D(1,637,665,823,665,823,700,637,700)",
#                 "span": {
#                   "offset": 414,
#                   "length": 4
#                 },
#                 "elements": [
#                   "/paragraphs/16"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 1,
#                 "columnIndex": 3,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "10%",
#                 "source": "D(1,823,665,1011,665,1011,700,823,700)",
#                 "span": {
#                   "offset": 428,
#                   "length": 3
#                 },
#                 "elements": [
#                   "/paragraphs/17"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 1,
#                 "columnIndex": 4,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$675",
#                 "source": "D(1,1011,665,1196,665,1196,700,1011,700)",
#                 "span": {
#                   "offset": 441,
#                   "length": 4
#                 },
#                 "elements": [
#                   "/paragraphs/18"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "10/13/2020",
#                 "source": "D(1,76,700,264,700,264,731,76,731)",
#                 "span": {
#                   "offset": 466,
#                   "length": 10
#                 },
#                 "elements": [
#                   "/paragraphs/19"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "Leadership Training",
#                 "source": "D(1,264,700,637,700,637,731,264,731)",
#                 "span": {
#                   "offset": 486,
#                   "length": 19
#                 },
#                 "elements": [
#                   "/paragraphs/20"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 2,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$750",
#                 "source": "D(1,637,700,823,700,824,731,637,731)",
#                 "span": {
#                   "offset": 515,
#                   "length": 4
#                 },
#                 "elements": [
#                   "/paragraphs/21"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 3,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "10%",
#                 "source": "D(1,823,700,1011,700,1011,731,824,731)",
#                 "span": {
#                   "offset": 529,
#                   "length": 3
#                 },
#                 "elements": [
#                   "/paragraphs/22"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 4,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$675",
#                 "source": "D(1,1011,700,1196,700,1196,731,1011,731)",
#                 "span": {
#                   "offset": 542,
#                   "length": 4
#                 },
#                 "elements": [
#                   "/paragraphs/23"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 3,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "10/14/2020",
#                 "source": "D(1,76,731,264,731,264,764,76,764)",
#                 "span": {
#                   "offset": 567,
#                   "length": 10
#                 },
#                 "elements": [
#                   "/paragraphs/24"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 3,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "Leadership Training",
#                 "source": "D(1,264,731,637,731,637,764,264,764)",
#                 "span": {
#                   "offset": 587,
#                   "length": 19
#                 },
#                 "elements": [
#                   "/paragraphs/25"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 3,
#                 "columnIndex": 2,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$750",
#                 "source": "D(1,637,731,824,731,824,764,637,764)",
#                 "span": {
#                   "offset": 616,
#                   "length": 4
#                 },
#                 "elements": [
#                   "/paragraphs/26"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 3,
#                 "columnIndex": 3,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "10%",
#                 "source": "D(1,824,731,1011,731,1011,764,824,764)",
#                 "span": {
#                   "offset": 630,
#                   "length": 3
#                 },
#                 "elements": [
#                   "/paragraphs/27"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 3,
#                 "columnIndex": 4,
#                 "rowSpan": 2,
#                 "columnSpan": 1,
#                 "content": "$675",
#                 "source": "D(1,1011,731,1196,731,1196,796,1011,796)",
#                 "span": {
#                   "offset": 655,
#                   "length": 4
#                 },
#                 "elements": [
#                   "/paragraphs/28"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 4,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "",
#                 "source": "D(1,76,764,264,764,264,796,76,796)",
#                 "span": {
#                   "offset": 680,
#                   "length": 0
#                 }
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 4,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "",
#                 "source": "D(1,264,764,637,764,637,796,264,796)",
#                 "span": {
#                   "offset": 690,
#                   "length": 0
#                 }
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 4,
#                 "columnIndex": 2,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "",
#                 "source": "D(1,637,764,824,764,824,796,637,796)",
#                 "span": {
#                   "offset": 700,
#                   "length": 0
#                 }
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 4,
#                 "columnIndex": 3,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "",
#                 "source": "D(1,824,764,1011,764,1011,796,824,796)",
#                 "span": {
#                   "offset": 710,
#                   "length": 0
#                 }
#               }
#             ],
#             "source": "D(1,76,628,1199,628,1199,796,76,796)",
#             "span": {
#               "offset": 240,
#               "length": 490
#             }
#           },
#           {
#             "rowCount": 3,
#             "columnCount": 2,
#             "cells": [
#               {
#                 "kind": "content",
#                 "rowIndex": 0,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "Subtotal",
#                 "source": "D(1,827,931,1013,932,1013,975,827,975)",
#                 "span": {
#                   "offset": 750,
#                   "length": 8
#                 },
#                 "elements": [
#                   "/paragraphs/29"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 0,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$2,025",
#                 "source": "D(1,1013,932,1194,932,1194,975,1013,975)",
#                 "span": {
#                   "offset": 768,
#                   "length": 6
#                 },
#                 "elements": [
#                   "/paragraphs/30"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 1,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "Sales Tax",
#                 "source": "D(1,827,975,1013,975,1013,1014,827,1014)",
#                 "span": {
#                   "offset": 795,
#                   "length": 9
#                 },
#                 "elements": [
#                   "/paragraphs/31"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 1,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "-",
#                 "source": "D(1,1013,975,1194,975,1195,1014,1013,1014)",
#                 "span": {
#                   "offset": 814,
#                   "length": 1
#                 },
#                 "elements": [
#                   "/paragraphs/32"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "Total",
#                 "source": "D(1,827,1014,1013,1014,1013,1055,826,1055)",
#                 "span": {
#                   "offset": 836,
#                   "length": 5
#                 },
#                 "elements": [
#                   "/paragraphs/33"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$2,025",
#                 "source": "D(1,1013,1014,1195,1014,1195,1055,1013,1055)",
#                 "span": {
#                   "offset": 851,
#                   "length": 6
#                 },
#                 "elements": [
#                   "/paragraphs/34"
#                 ]
#               }
#             ],
#             "source": "D(1,832,936,1198,936,1198,1053,831,1053)",
#             "span": {
#               "offset": 733,
#               "length": 144
#             }
#           }
#         ]
#       }
#     ]
#   },
#   "usage": {
#     "documentPages": 1,
#     "tokens": {
#       "contextualization": 1000,
#       "gpt-4o-input": 8735,
#       "gpt-4o-output": 884
#     }
#   }
# }

# %%
invoice_contents = invoice_result.get("result", {}).get("contents", [])
if invoice_contents:
    first_invoice = invoice_contents[0]
    print(json.dumps(first_invoice.get("fields", {}), indent=2))
else:
    print("No invoice fields returned in the analyzer response.")
# Out:
# {
#   "CustomerName": {
#     "type": "string",
#     "valueString": "Bellows College",
#     "spans": [
#       {
#         "offset": 84,
#         "length": 15
#       }
#     ],
#     "confidence": 0.534,
#     "source": "D(1,311.0198,233.8308,439.3728,236.0063,438.9971,258.1694,310.6442,255.9940)"
#   },
#   "InvoiceDate": {
#     "type": "date",
#     "valueDate": "2020-08-25",
#     "spans": [
#       {
#         "offset": 43,
#         "length": 9
#       }
#     ],
#     "confidence": 0.883,
#     "source": "D(1,1107.0000,157.0000,1191.0000,157.0000,1191.0000,178.0000,1107.0000,178.0000)"
#   },
#   "CustomerId": {
#     "type": "string",
#     "valueString": "1234567",
#     "spans": [
#       {
#         "offset": 147,
#         "length": 7
#       }
#     ],
#     "confidence": 0.594,
#     "source": "D(1,348.0000,362.0000,414.0000,362.0000,414.0000,380.0000,348.0000,380.0000)"
#   },
#   "PurchaseOrder": {
#     "type": "string",
#     "confidence": 0.741
#   },
#   "InvoiceId": {
#     "type": "string",
#     "valueString": "3579",
#     "spans": [
#       {
#         "offset": 70,
#         "length": 4
#       }
#     ],
#     "confidence": 0.867,
#     "source": "D(1,1141.0000,185.0000,1189.0000,184.0000,1189.0000,207.0000,1141.0000,207.0000)"
#   },
#   "DueDate": {
#     "type": "date",
#     "confidence": 0.856
#   },
#   "VendorName": {
#     "type": "string",
#     "valueString": "Contoso, Ltd.",
#     "spans": [
#       {
#         "offset": 0,
#         "length": 13
#       }
#     ],
#     "confidence": 0.826,
#     "source": "D(1,85.0000,62.0000,353.0000,62.0000,353.0000,121.0000,85.0000,121.0000)"
#   },
#   "VendorAddress": {
#     "type": "string",
#     "confidence": 0.717
#   },
#   "VendorAddressRecipient": {
#     "type": "string",
#     "confidence": 0.768
#   },
#   "CustomerAddress": {
#     "type": "string",
#     "valueString": "892 Hemlock Street\nSpruce City, NY, 84112",
#     "spans": [
#       {
#         "offset": 100,
#         "length": 18
#       },
#       {
#         "offset": 119,
#         "length": 22
#       }
#     ],
#     "confidence": 0.789,
#     "source": "D(1,310.0000,286.0000,468.0000,286.0000,468.0000,306.0000,310.0000,306.0000);D(1,310.0000,311.0000,493.0000,311.0000,493.0000,332.0000,310.0000,332.0000)"
#   },
#   "CustomerAddressRecipient": {
#     "type": "string",
#     "valueString": "Sold To Bellows College",
#     "spans": [
#       {
#         "offset": 76,
#         "length": 23
#       }
#     ],
#     "confidence": 0.434,
#     "source": "D(1,212.0313,232.1531,439.3728,236.0063,438.9687,259.8469,211.6272,255.9937)"
#   },
#   "BillingAddress": {
#     "type": "string",
#     "confidence": 0.945
#   },
#   "BillingAddressRecipient": {
#     "type": "string",
#     "confidence": 0.938
#   },
#   "ShippingAddress": {
#     "type": "string",
#     "confidence": 0.983
#   },
#   "ShippingAddressRecipient": {
#     "type": "string",
#     "confidence": 0.978
#   },
#   "SubTotal": {
#     "type": "number",
#     "valueNumber": 2025,
#     "spans": [
#       {
#         "offset": 768,
#         "length": 6
#       }
#     ],
#     "confidence": 0.691,
#     "source": "D(1,1034.0000,943.0000,1103.0000,943.0000,1103.0000,965.0000,1034.0000,966.0000)"
#   },
#   "TotalDiscount": {
#     "type": "number",
#     "confidence": 0.95
#   },
#   "TotalTax": {
#     "type": "number",
#     "spans": [
#       {
#         "offset": 814,
#         "length": 1
#       }
#     ],
#     "confidence": 0.476,
#     "source": "D(1,1035.0000,992.0000,1044.0000,992.0000,1044.0000,1000.0000,1035.0000,1001.0000)"
#   },
#   "InvoiceTotal": {
#     "type": "number",
#     "valueNumber": 2025,
#     "spans": [
#       {
#         "offset": 851,
#         "length": 6
#       }
#     ],
#     "confidence": 0.874,
#     "source": "D(1,1034.0000,1024.0000,1103.0000,1024.0000,1103.0000,1046.0000,1034.0000,1046.0000)"
#   },
#   "AmountDue": {
#     "type": "number",
#     "valueNumber": 2025,
#     "spans": [
#       {
#         "offset": 851,
#         "length": 6
#       }
#     ],
#     "confidence": 0.874,
#     "source": "D(1,1034.0000,1024.0000,1103.0000,1024.0000,1103.0000,1046.0000,1034.0000,1046.0000)"
#   },
#   "PreviousUnpaidBalance": {
#     "type": "number",
#     "confidence": 0.986
#   },
#   "RemittanceAddress": {
#     "type": "string",
#     "confidence": 0.911
#   },
#   "RemittanceAddressRecipient": {
#     "type": "string",
#     "confidence": 0.862
#   },
#   "ServiceAddress": {
#     "type": "string",
#     "confidence": 0.979
#   },
#   "ServiceAddressRecipient": {
#     "type": "string",
#     "confidence": 0.952
#   },
#   "VendorTaxId": {
#     "type": "string",
#     "confidence": 0.952
#   },
#   "CustomerTaxId": {
#     "type": "string",
#     "confidence": 0.922
#   },
#   "PaymentTerm": {
#     "type": "string",
#     "confidence": 0.833
#   },
#   "TaxDetails": {
#     "type": "array"
#   },
#   "Items": {
#     "type": "array",
#     "valueArray": [
#       {
#         "type": "object",
#         "valueObject": {
#           "TotalPrice": {
#             "type": "number",
#             "valueNumber": 675,
#             "spans": [
#               {
#                 "offset": 441,
#                 "length": 4
#               }
#             ],
#             "confidence": 0.611,
#             "source": "D(1,1085.0000,676.0000,1124.0000,676.0000,1124.0000,693.0000,1085.0000,694.0000)"
#           },
#           "Date": {
#             "type": "date",
#             "valueDate": "2020-10-12",
#             "spans": [
#               {
#                 "offset": 365,
#                 "length": 10
#               }
#             ],
#             "confidence": 0.884,
#             "source": "D(1,125.0000,675.0000,216.0000,675.0000,216.0000,695.0000,125.0000,695.0000)"
#           },
#           "Description": {
#             "type": "string",
#             "valueString": "Leadership Training",
#             "spans": [
#               {
#                 "offset": 385,
#                 "length": 19
#               }
#             ],
#             "confidence": 0.971,
#             "source": "D(1,372.0057,674.2735,529.1601,675.5013,528.9958,696.5312,371.8414,695.3034)"
#           },
#           "Quantity": {
#             "type": "number",
#             "confidence": 0.765
#           },
#           "ProductCode": {
#             "type": "string",
#             "confidence": 0.912
#           },
#           "TaxAmount": {
#             "type": "number",
#             "confidence": 0.805
#           },
#           "TaxRate": {
#             "type": "number",
#             "confidence": 0.777
#           },
#           "Unit": {
#             "type": "string",
#             "confidence": 0.701
#           },
#           "UnitPrice": {
#             "type": "number",
#             "valueNumber": 750,
#             "spans": [
#               {
#                 "offset": 414,
#                 "length": 4
#               }
#             ],
#             "confidence": 0.671,
#             "source": "D(1,711.0000,676.0000,750.0000,676.0000,750.0000,694.0000,711.0000,694.0000)"
#           }
#         }
#       },
#       {
#         "type": "object",
#         "valueObject": {
#           "TotalPrice": {
#             "type": "number",
#             "valueNumber": 675,
#             "spans": [
#               {
#                 "offset": 542,
#                 "length": 4
#               }
#             ],
#             "confidence": 0.94,
#             "source": "D(1,1086.0000,708.0000,1124.0000,708.0000,1124.0000,726.0000,1086.0000,726.0000)"
#           },
#           "Date": {
#             "type": "date",
#             "valueDate": "2020-10-13",
#             "spans": [
#               {
#                 "offset": 466,
#                 "length": 10
#               }
#             ],
#             "confidence": 0.941,
#             "source": "D(1,125.0000,707.0000,216.0000,707.0000,216.0000,727.0000,125.0000,727.0000)"
#           },
#           "Description": {
#             "type": "string",
#             "valueString": "Leadership Training",
#             "spans": [
#               {
#                 "offset": 486,
#                 "length": 19
#               }
#             ],
#             "confidence": 0.971,
#             "source": "D(1,372.0058,706.2599,529.1614,707.4973,528.9957,728.5433,371.8401,727.3058)"
#           },
#           "Quantity": {
#             "type": "number",
#             "confidence": 0.981
#           },
#           "ProductCode": {
#             "type": "string",
#             "confidence": 0.978
#           },
#           "TaxAmount": {
#             "type": "number",
#             "confidence": 0.974
#           },
#           "TaxRate": {
#             "type": "number",
#             "confidence": 0.95
#           },
#           "Unit": {
#             "type": "string",
#             "confidence": 0.943
#           },
#           "UnitPrice": {
#             "type": "number",
#             "valueNumber": 750,
#             "spans": [
#               {
#                 "offset": 515,
#                 "length": 4
#               }
#             ],
#             "confidence": 0.901,
#             "source": "D(1,711.0000,708.0000,750.0000,708.0000,750.0000,726.0000,711.0000,726.0000)"
#           }
#         }
#       },
#       {
#         "type": "object",
#         "valueObject": {
#           "TotalPrice": {
#             "type": "number",
#             "valueNumber": 675,
#             "spans": [
#               {
#                 "offset": 655,
#                 "length": 4
#               }
#             ],
#             "confidence": 0.906,
#             "source": "D(1,1086.0000,741.0000,1124.0000,741.0000,1124.0000,759.0000,1085.0000,759.0000)"
#           },
#           "Date": {
#             "type": "date",
#             "valueDate": "2020-10-14",
#             "spans": [
#               {
#                 "offset": 567,
#                 "length": 10
#               }
#             ],
#             "confidence": 0.933,
#             "source": "D(1,125.0000,740.0000,216.0000,741.0000,216.0000,760.0000,125.0000,760.0000)"
#           },
#           "Description": {
#             "type": "string",
#             "valueString": "Leadership Training",
#             "spans": [
#               {
#                 "offset": 587,
#                 "length": 19
#               }
#             ],
#             "confidence": 0.965,
#             "source": "D(1,372.0086,739.2361,529.2359,741.0027,529.0000,762.0000,371.7727,760.2334)"
#           },
#           "Quantity": {
#             "type": "number",
#             "confidence": 0.938
#           },
#           "ProductCode": {
#             "type": "string",
#             "confidence": 0.971
#           },
#           "TaxAmount": {
#             "type": "number",
#             "confidence": 0.974
#           },
#           "TaxRate": {
#             "type": "number",
#             "confidence": 0.941
#           },
#           "Unit": {
#             "type": "string",
#             "confidence": 0.935
#           },
#           "UnitPrice": {
#             "type": "number",
#             "valueNumber": 750,
#             "spans": [
#               {
#                 "offset": 616,
#                 "length": 4
#               }
#             ],
#             "confidence": 0.906,
#             "source": "D(1,711.0000,741.0000,750.0000,741.0000,750.0000,759.0000,711.0000,759.0000)"
#           }
#         }
#       }
#     ]
#   }
# }
